# %% [markdown]
# ---
# layout: post
# title: UESL 3.01 Homework
# author: Ainsleyalbert
# permalink: /homework/3-1/
# ---

# %% [markdown]
# Popcorn hack

# %%
stars = 8
checkpoint_stars = stars
stars = stars + 4
print(stars)
print(checkpoint_stars)

# %% [markdown]
# homwork part 1:

# %% [markdown]
# 1: B
# 2: A
# 3: C
# 4: B

# %% [markdown]
# Homework part 2:

# %%
game_name = "Star Quest"
reduced_motion = True

level_one_stars = 12
level_two_stars = 18
level_three_stars = 10

total = level_one_stars + level_two_stars + level_three_stars

print("Game:", game_name)
print("Reduced motion:", reduced_motion)
print("Total:", total)

level_two_stars = level_two_stars + 5

print("Stored total:", total)

total = level_one_stars + level_two_stars + level_three_stars
print("Updated total:", total)

print("Prediction: original/stored total = 40")
print("Actual: original/stored total = 40")
print("Prediction: updated total = 45")
print("Actual: updated total = 45")

level_one_stars = 12
level_two_stars = 18
level_three_stars = 10

total = level_one_stars + level_two_stars + level_three_stars

print("Restart total:", total)
