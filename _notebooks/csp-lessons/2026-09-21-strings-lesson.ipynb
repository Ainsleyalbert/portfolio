# %% [markdown]
# ---
# layout: post
# categories: [Python, Mathematical-Expressions]
# lesson_language: Python
# lesson_topic: Mathematical-Expressions
# lesson_part: interactive
# lesson_type: lesson
# title: 3.3 Math Expressions HW
# permalink: /python/strings-intercepters
# Authors: Ainsleyalbert
# ---
# Popcorn hack 1:
#
# raw = " Agent-Zero says: the drop is at MIDNIGHT!!! "
#
# print(raw[35:43])
#
# clean = raw.strip()
#
# Popcorn hack 2:
#
# agent = "Falcon"
# status = "confirmed"
# count = 3
#
# report = agent + " status: " + status
# report_with_number = agent + " intercepted " + str(count) + " signals"
#
# report_f = f"{agent} status: {status} ({count} signals intercepted)"
#
# parts = ["ALPHA", "BRAVO", "CHARLIE"]
# print("-".join(parts).lower().replace("-", " "))
#
# raw = " AGENT-FALCON!!! Status: CONFIRMED... "
#
# Popcorn hack 3:
# raw_transmission = " 2026-09-15,GHOST,THE-EAGLE-LANDS-AT-DAWN,87 "
#
# segments = raw_transmission.strip().split(",")
# print("Segments:", segments)
#
# date = segments[0]
# agent = segments[1]
# message_code = segments[2]
# confidence_str = segments[3]
# print("Date:", date, "| Agent:", agent, "| Message code:", message_code, "| Confidence:", confidence_str)
#
# year_check = date[:4]
# print("Year check:", year_check)
#
# message = message_code.replace("-", " ")
# print("Message:", message)
#
# confidence = int(confidence_str)
#
# identifier = " | ".join([date, agent, message])
#
# report = agent + " intercept: " + message + " (confidence " + str(confidence) + "%)"
#
# final_report = f"{date} - {agent} - {message} - Confidence: {confidence}%"
#
# print("Identifier:", identifier)
# print("Report:", report)
# print("Final report:", final_report)
#
# Homework:
#
# raw_transmission = "  2026-09-15,GHOST,THE-EAGLE-LANDS-AT-DAWN,87  "
#
# segments = raw_transmission.strip().split(",")
# print("Segments:", segments)
#
# date = segments[0]
# agent = segments[1]
# message_code = segments[2]
# confidence_str = segments[3]
# print("Date:", date, "| Agent:", agent, "| Message code:", message_code, "| Confidence:", confidence_str)
#
# year_check = date[:4]
# print("Year check:", year_check)
#
# message = message_code.replace("-", " ")
#
# found_dawn = "dawn" in message.lower()
# print("Found 'dawn':", found_dawn)
#
# markdown_row = f"| {date} | {agent} | {message} | {confidence_str}% |"
# print("Markdown row:", markdown_row)
#
# json_line = f'{{"date": "{date}", "agent": "{agent}", "message": "{message}", "confidence": {confidence_str}, "contains_dawn": {str(found_dawn).lower()}}}'
# print("JSON line:", json_line)
